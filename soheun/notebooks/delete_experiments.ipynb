# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
os.chdir('/home/export/soheuny/SRFinder/soheun')

# %%
features = [
    "sym_Jet0_pt", "sym_Jet1_pt", "sym_Jet2_pt", "sym_Jet3_pt",
    "sym_Jet0_eta", "sym_Jet1_eta", "sym_Jet2_eta", "sym_Jet3_eta",
    "sym_Jet0_phi", "sym_Jet1_phi", "sym_Jet2_phi", "sym_Jet3_phi",  
    "sym_Jet0_m", "sym_Jet1_m", "sym_Jet2_m", "sym_Jet3_m",
]

# %%
import torch
from fvt_classifier import FvTClassifier
from tst_info import TSTInfo
from training_info import TrainingInfo
import yaml
import matplotlib.pyplot as plt

experiment_name = "counting_test_high_4b_in_CR"
hparams_filter = {
    "experiment_name": experiment_name,
    "n_3b": 140_0000,
}
hashes, params = TSTInfo.find(hparam_filter=hparams_filter, return_hparams=True)
# Out:
# 0it [00:00, ?it/s]
# 1793it [00:02, 819.19it/s]

# %%
# # Delete data/tst_info/{hash}

# import os

# for hash in hashes:
#     hash_dir = os.path.join("data/tst_info", hash)
#     os.system(f"rm {hash_dir}")

# %%
# # Delete data/training_info/{hash}

# import os

# for hash in hashes:
#     hash_dir = os.path.join("data/training_info", hash)
#     os.system(f"rm {hash_dir}")

# %%
print(experiment_name)
hashes = TrainingInfo.find(
    {"experiment_hparams": lambda x: x["experiment_name"] == experiment_name if isinstance(x, dict) else False}
)
hashes
# Out:
# counting_test_v2
# 1980it [00:01, 1740.04it/s]
# []

# %%
# Delete data/training_info/{hash}

# import os

# for hash in hashes:
#     hash_dir = os.path.join("data/training_info", hash)
#     os.system(f"rm {hash_dir}")

# %%
print(experiment_name)
hashes = TrainingInfo.find(
    {"experiment_hparams": lambda x: x["experiment_name"] == "counting_test_v1" if isinstance(x, dict) else False}
)
hashes
# Out:
# counting_test_v2
# 0it [00:00, ?it/s]
# 1980it [00:01, 1926.26it/s]
# ['0UAqFzWsDK4F',
#  'rUMp48Y3tT3Q',
#  'DgAL47D1qXIa',
#  'SyZPaE1pu1lJ',
#  'o7XBetF5gIRH',
#  'YH7LKBKxJsll',
#  'LODfU25035Hy',
#  'RrY03K6JBO94',
#  'XfLEN0pThnXu',
#  'YgjRcJ4HQbNL',
#  'Jyw8cb7lhnX6',
#  'bAgqnOvlFcg9',
#  'i0VpEBOWfbZA',
#  'VaBSo63bbH6x',
#  'nAbnBEoonCrb',
#  'ZINl91huSS6A',
#  'ZPsK20FKcpXz',
#  'kIRPxBFWGyEb',
#  'cR8KykF8VH1o',
#  'F7JCqH7aWY2T',
#  'YGIAd1JmFEwv',
#  'HMLCbokK1XXY',
#  'p0PfbaUpgMve',
#  'jGkqSCtDbxAl',
#  '76dfZTPtLLKj',
#  'AyS96HBqcbCt',
#  'x3GIobuiF9Pl',
#  '3XT4VWv87jUS',
#  'CGE5FZv23CJ5',
#  'SEnuRk4q4t7R',
#  'FGOKtmF5MeYT',
#  '4lUdOqo2gG0p',
#  'n2ASbwkPf7bT',
#  'bpYjlQxc9jcv',
#  'MUhubBVT3U1R',
#  'DnOtgB2hKyFi',
#  'oHwLMeaZqo9D',
#  'ZDNjN1GTPdVK',
#  'sb1DS2S5yXB6',
#  '2gin7BMsFxvK',
#  'K4Q519Pk174J',
#  'SnZJrd09fXzj',
#  'sV2cMcSu28F9',
#  'teLbmzLjc1t7',
#  '3xCGNKIM6FAS',
#  'os8GIazJbMNd',
#  'MCQvRTbdP7pC',
#  'KtwtwKsxVbJT',
# ...
